# %%
Organizing the list Data type:

# %%
students=['somu','lakshmi','giri','kumar','mouni','malik']

# %%
print(students)
# Out:
# ['somu', 'lakshmi', 'giri', 'kumar', 'mouni', 'malik']

# %%
# I want to print the 'lakshmi' name in the list, what is the index for it......?

# %%
print(students[1])
# Out:
# lakshmi

# %%
print(students[1].title())
# Out:
# Lakshmi

# %%
# I want to print the above list in alphabetical order A..Z

# %%
#Two approches:

1.temp approach:------>sorted=====>We can retain the original order
    
2.Permanent approach:-->sort====>Changes are applied permanetly

# %%
print(sorted(students))
# Out:
# ['giri', 'kumar', 'lakshmi', 'malik', 'mouni', 'somu']

# %%
print(students)#retaining the original order
# Out:
# ['somu', 'lakshmi', 'giri', 'kumar', 'mouni', 'malik']

# %%
students.sort()

# %%
print(students)
# Out:
# ['giri', 'kumar', 'lakshmi', 'malik', 'mouni', 'somu']

# %%
print(students)# changes are applied permanetly
# Out:
# ['giri', 'kumar', 'lakshmi', 'malik', 'mouni', 'somu']

# %%
Interview quwstion what is the difference between sorted and sort methis in the list....?

# %%
# I want to print the list in the reverse order..?

# %%
students.reverse()

# %%
print(students)
# Out:
# ['somu', 'mouni', 'malik', 'lakshmi', 'kumar', 'giri']

# %%
# I want to count the number of list in the list..?

# %%
len(students)
# Out:
# 6

# %%
slicing of the list data type:

# %%
print(students)
# Out:
# ['somu', 'mouni', 'malik', 'lakshmi', 'kumar', 'giri']

# %%
#general sysntax for slicing

# %%
print(list(start value:stop value:step count))

# %%
Note: Stop value is always exclusive. +1 to include the stop value.{will add the one value to index of the stop value}

# %%
#req  I want to include the 'somu' and 'mouni' in the list

# %%
print(students[0:1])
# Out:
# ['somu']

# %%
print(students[0:2])
# Out:
# ['somu', 'mouni']

# %%
print(students[2:4])
# Out:
# ['malik', 'lakshmi']

# %%
print(students[4:6])
# Out:
# ['kumar', 'giri']

# %%
print(students[0:8:2])
# Out:
# ['somu', 'malik', 'kumar']

# %%
print(students[0:6:3])
# Out:
# ['somu', 'lakshmi']

# %%
print(students[1:6:2])
# Out:
# ['mouni', 'lakshmi', 'giri']

# %%
print(students[1:5:2])
# Out:
# ['mouni', 'lakshmi']
