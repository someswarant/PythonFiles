# %%
Introduction to lit datatype:

# %%
Definition: A list is acollection of item declared in aparticular order
    classification:it sis classified as mutable datatype
How to Declare the list datatype......?[]

# %%
students=['somu','giri','kumar','lakshmi','kanthamma','muni']

# %%
# 0,1,2,3,4,5[Position of the names in the list]

# %%
print(students)
# Out:
# ['somu', 'giri', 'kumar', 'lakshmi', 'kanthamma', 'muni']

# %%
type(students)
# Out:
# list

# %%
#How to access the abov elements in the list....?

# %%
Introducing indexing 0,1,2,3,.....

# %%
# I want to access the Kumar from the list...?

# %%
print(students[2])
# Out:
# kumar

# %%
1.How to add the new element to the list
2.How to mmodify the element in the list
3.How to delete the elements in the list

# %%
print(students)
# Out:
# ['somu', 'giri', 'kumar', 'lakshmi', 'kanthamma', 'muni']

# %%
#I want to add the sachin name to the above list

# %%
students.append('sachin')

# %%
print(students)
# Out:
# ['somu', 'giri', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin']

# %%
# Addng another name to the list

# %%
students.append('mouni')

# %%
print(students)
# Out:
# ['somu', 'giri', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']

# %%
# I want to add the malik name in the 2nd index....?

# %%
students.insert(2,'malik')

# %%
print(students)
# Out:
# ['somu', 'giri', 'malik', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']

# %%
print(students[2])
# Out:
# malik

# %%
# What is the difference between the append and insert in the list....? Interview question

# %%
# How to modify the elements in the list...?

# %%
print(students)
# Out:
# ['somu', 'giribabu', 'malik', 'malik', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']

# %%
# I want t modify giri name as 'giribabu'

# %%
print(students[1])
# Out:
# giri

# %%
students[1]='giribabu'

# %%
print(students[1])
# Out:
# giribabu

# %%
print(students)
# Out:
# ['somu', 'giribabu', 'malik', 'malik', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']

# %%
#How to delete the element in the list

# %%
print(students)
# Out:
# ['somu', 'giribabu', 'malik', 'malik', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']

# %%
# I want to delete the 'malik name in the list'

# %%
del students[2]

# %%
print(students)
# Out:
# ['somu', 'giribabu', 'malik', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']

# %%
del students[2]

# %%
print(students)
# Out:
# ['somu', 'giribabu', 'kumar', 'lakshmi', 'kanthamma', 'muni', 'sachin', 'mouni']
