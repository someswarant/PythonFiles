# %%
Hello='hello someswaran welcome to python learning'

print(Hello.upper())
# Out:
# HELLO SOMESWARAN WELCOME TO PYTHON LEARNING

# %%
print(Hello.title())
# Out:
# Hello Someswaran Welcome To Python Learning

# %%
print(Hello.lower())
# Out:
# hello someswaran welcome to python learning

# %%
type(Hello)
# Out:
# str

# %%
print('Hello\nsomeswaran\nwelcome\nto\npython\nlearning')
# Out:
# Hello
# someswaran
# welcome
# to
# python
# learnig

# %%
print('Hello\tsomeswaran\twelcome\tto\tpython\tlearning')
# Out:
# Hello	someswaran	welcome	to	python	learning
